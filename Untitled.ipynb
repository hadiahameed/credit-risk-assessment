# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_original = pd.read_csv('credit_risk_dataset.csv')
df_original.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
df_original.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# 50%        10.990000      0.000000             0.150000
# 75%        13.470000      0.000000             0.230000
# max        23.220000      1.000000             0.830000
#
#        cb_person_cred_hist_length
# count                32581.000000
# mean                     5.804211
# std                      4.055001
# min                      2.000000
# 25%                      3.000000
# 50%                      4.000000
# 75%                      8.000000
# max                     30.000000

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
df = df_original.copy()

# %%
fig, axes = plt.subplots(2,3,figsize=(18,9))
fig.suptitle('Distribution of numerical variables')

sns.histplot(x=df['person_age'],ax=axes[0,0])
sns.histplot(x=df['person_income'],ax=axes[0,1])
sns.histplot(x=df['person_emp_length'],ax=axes[0,2])
sns.histplot(x=df['loan_amnt'],ax=axes[1,0])
sns.histplot(x=df['loan_int_rate'],ax=axes[1,0])
sns.histplot(x=df['loan_percent_income'],ax=axes[1,1])
sns.histplot(x=df['cb_person_cred_hist_length'],ax=axes[1,2])
# Out:
# <AxesSubplot:xlabel='cb_person_cred_hist_length', ylabel='Count'>

# %%
age_threshold = 100
income_threshold = 1000000
emp_length_threshold = 30
print('Percentage of records removed')
print('Person\'s age - with a thresold of ',age_threshold,' :', 100*df[df['person_age']>age_threshold].shape[0]/df.shape[0], '%. Count (rows): ',df[df['person_age']>age_threshold].shape[0])
print('Person\'s income - with a thresold of ',income_threshold,' :', 100*df[df['person_income']>income_threshold].shape[0]/df.shape[0], '%. Count (rows): ',df[df['person_income']>income_threshold].shape[0])
# Out:
# Percentage of records removed
# Person's age - with a thresold of  100  : 0.015346367514809245 %. Count (rows):  5
# Person's income - with a thresold of  1000000  : 0.02762346152665664 %. Count (rows):  9

# %%
print('Thresholding age:')
print('Total Number of rows: ', df.shape[0])
df = df[df['person_age']<age_threshold]
print('Total Number of rows: ', df.shape[0])
# Out:
# Thresholding age:
# Total Number of rows:  32581
# Total Number of rows:  32576

# %%
print('Thresholding income:')
print('Total Number of rows: ', df.shape[0])
df = df[df['person_income']<income_threshold]
print('Total Number of rows: ', df.shape[0])
# Out:
# Thresholding income:
# Total Number of rows:  32576
# Total Number of rows:  32568

# %%
sns.countplot(x=df['loan_status']);

# %%
sns.scatterplot(x='person_income', y='person_age', hue = 'loan_status', data=df);
